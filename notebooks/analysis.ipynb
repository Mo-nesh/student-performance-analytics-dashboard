# %% [markdown]
# # Student Performance Analytics Dashboard
# **Author:** Monesh R

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('data/student_performance.csv')
df.head()

# %% [markdown]
# ## Dataset Overview

# %%
df.info()
df.describe()

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# ## KPI Analysis

# %%
print(df.columns)

# %% [markdown]
# ## Visualization

# %%
if 'Attendance' in df.columns:
 df['Attendance'].hist(); plt.show()

# %% [markdown]
# ## Insights
# - Attendance trends
# - Student performance
# - KPI reporting
